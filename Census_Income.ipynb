# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/census-income  (1).csv")

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country annual_income
# 0          2174             0              40  United-States         <=50K
# ...

# %%
df.tail()
# Out:
#        age     workclass  fnlwgt   education  education-num  \
# 32556   27       Private  257302  Assoc-acdm             12
# 32557   40       Private  154374     HS-grad              9
# 32558   58       Private  151910     HS-grad              9
# 32559   22       Private  201490     HS-grad              9
# 32560   52  Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation relationship   race     sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical    Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country annual_income
# 32556             0             0              38  United-States         <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  annual_income   32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'annual_income'],
#       dtype='object')

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.describe(include='object')
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32561     32561               32561           32561        32561
# unique         9        16                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22696     10501               14976            4140        13193
#
#          race    sex native-country annual_income
# count   32561  32561          32561         32561
# unique      5      2             42             2
# top     White   Male  United-States         <=50K
# freq    27816  21790          29170         24720

# %%
df['annual_income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
df['annual_income'].value_counts()
# Out:
# annual_income
# <=50K    24720
# >50K      7841
# Name: count, dtype: int64

# %% [markdown]
# #Target is categorical
# #There are two target classes
# #Dataset has both numerical and categorical input features
# #Dataset has 32,561 rows
# #We will need encoding before most sklearn models can use the categorical features
# #So,Random Forest can be the best model to predict the features

# %%
#To rename the target column
df.rename(columns={'annual_income':'income'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df['income'].shape
# Out:
# (32561,)

# %%
df['income'].dtype
# Out:
# dtype('O')

# %%
df['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
df['income'].value_counts()
# Out:
# income
# <=50K    24720
# >50K      7841
# Name: count, dtype: int64

# %%
#to check for the special characters in a dataset
(df=='?').sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# income               0
# dtype: int64

# %%
(df=="?").sum().sum()
# Out:
# np.int64(0)

# %%
df=df.replace("?",np.nan)

# %%
(df=="?").sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# income               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(24)

# %%
for col in ['workclass','occupation','native-country']:
  df[col] =df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
columns=['hours-per-week','age','education-num','fnlwgt']
for col in columns:
  Q1=df[col].quantile(0.25)
  Q3=df[col].quantile(0.75)
  IQR=Q3-Q1
  lower_bound=Q1-1.5*IQR
  upper_bound=Q3+1.5*IQR
  outliers=df[(df[col]<lower_bound)|(df[col]>upper_bound)]
  print(col)
  print("Q1:",Q1)
  print("Q3:",Q3)
  print("IQR:",IQR)
  print("Lower Bound:",lower_bound)
  print("Upper Bound:",upper_bound)
  print("Number of Outliers:",len(outliers))
# Out:
# hours-per-week
# Q1: 40.0
# Q3: 45.0
# IQR: 5.0
# Lower Bound: 32.5
# Upper Bound: 52.5
# Number of Outliers: 9002
# age
# Q1: 28.0
# Q3: 48.0
# IQR: 20.0
# Lower Bound: -2.0
# Upper Bound: 78.0
# Number of Outliers: 142
# education-num
# Q1: 9.0
# Q3: 12.0
# IQR: 3.0
# Lower Bound: 4.5
# Upper Bound: 16.5
# Number of Outliers: 1193
# fnlwgt
# Q1: 117827.0
# Q3: 236993.0
# IQR: 119166.0
# Lower Bound: -60922.0
# Upper Bound: 415742.0
# Number of Outliers: 993

# %%
df.shape
# Out:
# (32537, 15)

# %%
columns=['hours-per-week','age','education-num','fnlwgt']
for col in columns:
  Q1=df[col].quantile(0.25)
  Q3=df[col].quantile(0.75)
  IQR=Q3-Q1
  lower_bound=Q1-1.5*IQR
  upper_bound=Q3+1.5*IQR
  df=df[(df[col]>=lower_bound)&(df[col]<=upper_bound)]
  print(col, ":", len(outliers))
# Out:
# hours-per-week : 993
# age : 993
# education-num : 993
# fnlwgt : 993

# %%
#Encoding
y=df['income']
x=df.drop('income',axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)

# %%
x.select_dtypes(include='object').columns
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country'],
#       dtype='object')

# %%
x = pd.get_dummies(x, drop_first=True, dtype=int) #pd.get_dummies is used to convert categorical columns to numerical columns

# %%
x.head()
# Out:
#    age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 0   39   77516             13          2174             0              40
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40
# 5   37  284582             14             0             0              40
#
#    workclass_Local-gov  workclass_Never-worked  workclass_Private  \
# 0                    0                       0                  0
# 2                    0                       0                  1
# 3                    0                       0                  1
# 4                    0                       0                  1
# 5                    0                       0                  1
#
#    workclass_Self-emp-inc  ...  native-country_Portugal  \
# 0                       0  ...                        0
# ...

# %%
x.shape
# Out:
# (16837, 93)

# %%
x.dtypes
# Out:
# age                               int64
# fnlwgt                            int64
# education-num                     int64
# capital-gain                      int64
# capital-loss                      int64
#                                   ...
# native-country_Thailand           int64
# native-country_Trinadad&Tobago    int64
# native-country_United-States      int64
# native-country_Vietnam            int64
# native-country_Yugoslavia         int64
# Length: 93, dtype: object

# %%
print(x.shape)
print(y.shape)
# Out:
# (16837, 93)
# (16837,)

# %%
print(x.head())
print(y[:5])
# Out:
#    age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 0   39   77516             13          2174             0              40
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40
# 5   37  284582             14             0             0              40
#
#    workclass_Local-gov  workclass_Never-worked  workclass_Private  \
# 0                    0                       0                  0
# 2                    0                       0                  1
# 3                    0                       0                  1
# 4                    0                       0                  1
# 5                    0                       0                  1
#
#    workclass_Self-emp-inc  ...  native-country_Portugal  \
# 0                       0  ...                        0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print("x_train:", x_train.shape)
print("x_test:", x_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# x_train: (13469, 93)
# x_test: (3368, 93)
# y_train: (13469,)
# y_test: (3368,)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy score:",accuracy)
# Out:
# Accuracy score: 0.8470902612826603

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[2373  180]
#  [ 335  480]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      2553
#            1       0.73      0.59      0.65       815
#
#     accuracy                           0.85      3368
#    macro avg       0.80      0.76      0.78      3368
# weighted avg       0.84      0.85      0.84      3368
